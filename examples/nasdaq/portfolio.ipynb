# %%
from utils_dir import get_curr_dir, include_home_dir
include_home_dir()

import pandas as pd
import numpy as np

from jumpmodels.utils import filter_date_range
from jumpmodels.jump import JumpModel
from jumpmodels.sparse_jump import SparseJumpModel
from jumpmodels.plot import plot_regimes_and_cumret, savefig_plt

from get_data import get_data
from feature import DataLoader

from datetime import timedelta

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Import the process_updates function
from portfolio_utils import process_updates  # Replace 'your_module' with the actual module name

# %%
# Define the portfolio
portfolio = ['AAPL', 'AMZN', 'META', 'MSFT', 'NVDA', 'PLTR', 'RDDT', 'RIVN', 'VOO']

# Process updates for each ticker in the portfolio
for ticker in portfolio:
    print(f"Processing updates for {ticker}")
    process_updates(ticker)
    print(f"Finished processing {ticker}\n")

# %%
print("All updates processed successfully.")
